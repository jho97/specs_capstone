# %% [markdown]
# # Colorado Economic Figures
# ##### The data set i'm looking over is from the Federal Reserve Economic Data https://fred.stlouisfed.org and I found it to be reliable because the data was taken from the US Census.

# %%
import pandas as pd
import numpy as np 
import plotly.express as px

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df_gdp = pd.read_csv("../state_gdp/colorado_gdp_cleaned.csv")
df_household = pd.read_csv("../state_med_household_income/colorado_household_income_cleaned.csv")
df_pop = pd.read_csv("../state_pop/colorado_pop_cleaned.csv")
df_taxes = pd.read_csv("../state_tax_collection/colorado_taxes_cleaned.csv")

# %%
# colorado gdp
df_gdp.head()
df_gdp.info()
# normalized data
from sklearn import preprocessing
gdp_scaler = preprocessing.MinMaxScaler()
gdp_names = df_gdp.columns
gdp_d = gdp_scaler.fit_transform(df_gdp)
gdp_scaled_df = pd.DataFrame(gdp_d, columns=gdp_names)
gdp_scaled_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   year                25 non-null     int64
#  1   dollars (millions)  25 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 528.0 bytes
#         year  dollars (millions)
# 0   0.000000            0.000000
# 1   0.041667            0.047120
# 2   0.083333            0.094248
# 3   0.125000            0.151432
# 4   0.166667            0.174700
# 5   0.208333            0.186359
# 6   0.250000            0.207786
# 7   0.291667            0.235994
# 8   0.333333            0.294289
# 9   0.375000            0.335908
# 10  0.416667            0.391337
# 11  0.458333            0.427911
# 12  0.500000            0.401094
# 13  0.541667            0.425906
# 14  0.583333            0.458238
# 15  0.625000            0.490889
# 16  0.666667            0.544626
# 17  0.708333            0.605677
# 18  0.750000            0.644894
# 19  0.791667            0.677137
# 20  0.833333            0.743746
# 21  0.875000            0.822775
# 22  0.916667            0.895723
# 23  0.958333            0.861927
# 24  1.000000            1.000000

# %%
# colorado median household income
df_household.head()
df_household.info()
# normalized data
from sklearn import preprocessing
household_scaler = preprocessing.MinMaxScaler()
household_names = df_household.columns
household_d = household_scaler.fit_transform(df_household)
household_scaled_df = pd.DataFrame(household_d, columns=household_names)
household_scaled_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   year     37 non-null     int64
#  1   dollars  37 non-null     int64
# dtypes: int64(2)
# memory usage: 720.0 bytes
#         year   dollars
# 0   0.000000  0.253711
# 1   0.027778  0.374710
# 2   0.055556  0.256736
# 3   0.083333  0.129792
# 4   0.111111  0.039360
# 5   0.138889  0.000000
# 6   0.166667  0.176504
# 7   0.194444  0.153465
# 8   0.222222  0.166338
# 9   0.250000  0.240063
# 10  0.277778  0.400035
# 11  0.305556  0.516778
# 12  0.333333  0.468097
# 13  0.361111  0.547415
# 14  0.388889  0.703060
# 15  0.416667  0.735174
# 16  0.444444  0.651847
# 17  0.472222  0.640696
# 18  0.500000  0.545199
# 19  0.527778  0.572459
# 20  0.555556  0.552972
# 21  0.583333  0.451987
# 22  0.611111  0.615512
# 23  0.638889  0.785649
# 24  0.666667  0.677700
# 25  0.694444  0.473444
# 26  0.722222  0.614914
# 27  0.750000  0.472810
# 28  0.777778  0.368871
# 29  0.805556  0.752902
# 30  0.833333  0.440204
# 31  0.861111  0.653535
# 32  0.888889  0.771579
# 33  0.916667  0.879318
# 34  0.944444  0.742314
# 35  0.972222  0.676152
# 36  1.000000  1.000000

# %%
# colorado population
df_pop.head()
df_pop.info()

from sklearn import preprocessing
pop_scaler = preprocessing.MinMaxScaler()
pop_names = df_pop.columns
pop_d = pop_scaler.fit_transform(df_pop)
pop_scaled_df = pd.DataFrame(pop_d, columns=pop_names)
pop_scaled_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          122 non-null    int64
#  1   colorado_pop  122 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 2.0 KB
#          year  colorado_pop
# 0    0.000000      0.000000
# 1    0.008264      0.007212
# 2    0.016529      0.014803
# 3    0.024793      0.020687
# 4    0.033058      0.022015
# 5    0.041322      0.026001
# 6    0.049587      0.031125
# 7    0.057851      0.036060
# 8    0.066116      0.040614
# 9    0.074380      0.044031
# 10   0.082645      0.049534
# 11   0.090909      0.052761
# 12   0.099174      0.054848
# 13   0.107438      0.055418
# 14   0.115702      0.057505
# 15   0.123967      0.061681
# 16   0.132231      0.066236
# 17   0.140496      0.069652
# 18   0.148760      0.068893
# 19   0.157025      0.074966
# 20   0.165289      0.074776
# 21   0.173554      0.079331
# 22   0.181818      0.080090
# 23   0.190083      0.083696
# 24   0.198347      0.089390
# 25   0.206612      0.090339
# 26   0.214876      0.089769
# 27   0.223140      0.092047
# 28   0.231405      0.089390
# 29   0.239669      0.088251
# 30   0.247934      0.094324
# 31   0.256198      0.097361
# 32   0.264463      0.099259
# 33   0.272727      0.100207
# 34   0.280992      0.100967
# 35   0.289256      0.101536
# 36   0.297521      0.103813
# 37   0.305785      0.106470
# 38   0.314050      0.107989
# 39   0.322314      0.109507
# 40   0.330579      0.111405
# 41   0.338843      0.110266
# 42   0.347107      0.108179
# 43   0.355372      0.115770
# 44   0.363636      0.112733
# 45   0.371901      0.108748
# 46   0.380165      0.125259
# 47   0.388430      0.131712
# 48   0.396694      0.136647
# 49   0.404959      0.142720
# 50   0.413223      0.148413
# 51   0.421488      0.148603
# 52   0.429752      0.156005
# 53   0.438017      0.168531
# 54   0.446281      0.180298
# 55   0.454545      0.190356
# 56   0.462810      0.205349
# 57   0.471074      0.212751
# 58   0.479339      0.213320
# 59   0.487603      0.221481
# 60   0.495868      0.232679
# 61   0.504132      0.246913
# 62   0.512397      0.257351
# 63   0.520661      0.264373
# 64   0.528926      0.270826
# 65   0.537190      0.273673
# 66   0.545455      0.277848
# 67   0.553719      0.286578
# 68   0.561983      0.299294
# 69   0.570248      0.308024
# 70   0.578512      0.316298
# 71   0.586777      0.334124
# 72   0.595041      0.353311
# 73   0.603306      0.370629
# 74   0.611570      0.379271
# 75   0.619835      0.387771
# 76   0.628099      0.396523
# 77   0.636364      0.408638
# 78   0.644628      0.422038
# 79   0.652893      0.437693
# 80   0.661157      0.448998
# 81   0.669421      0.462112
# 82   0.677686      0.477990
# 83   0.685950      0.491668
# 84   0.694215      0.498569
# 85   0.702479      0.505919
# 86   0.710744      0.511371
# 87   0.719008      0.515742
# 88   0.727273      0.516084
# 89   0.735537      0.518653
# 90   0.743802      0.523975
# 91   0.752066      0.536066
# 92   0.760331      0.553607
# 93   0.768595      0.572755
# 94   0.776860      0.590410
# 95   0.785124      0.606381
# 96   0.793388      0.620549
# 97   0.801653      0.635462
# 98   0.809917      0.650203
# 99   0.818182      0.666746
# 100  0.826446      0.718138
# 101  0.834711      0.736883
# 102  0.842975      0.749166
# 103  0.851240      0.756440
# 104  0.859504      0.765223
# 105  0.867769      0.776017
# 106  0.876033      0.792820
# 107  0.884298      0.808657
# 108  0.892562      0.824952
# 109  0.900826      0.840603
# 110  0.909091      0.854902
# 111  0.917355      0.869015
# 112  0.925620      0.882634
# 113  0.933884      0.897269
# 114  0.942149      0.912806
# 115  0.950413      0.932105
# 116  0.958678      0.949094
# 117  0.966942      0.963058
# 118  0.975207      0.978191
# 119  0.983471      0.989831
# 120  0.991736      0.994731
# 121  1.000000      1.000000

# %%
# colorado taxed income
df_taxes.head()
df_taxes.info()
from sklearn import preprocessing
scaler = preprocessing.MinMaxScaler()
names = df.columns
d = scaler.fit_transform(df)
scaled_df = pd.DataFrame(d, columns=names)
scaled_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   year     72 non-null     int64
#  1   dollars  72 non-null     int64
# dtypes: int64(2)
# memory usage: 1.2 KB
