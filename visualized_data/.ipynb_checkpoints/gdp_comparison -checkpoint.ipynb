# %% [markdown]
# # Washington and Idaho Comparison
#
# ### In current dollars

# %%
import pandas as pd
import numpy as np 
import plotly.express as px

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# import data
washington_df = pd.read_csv("../state_gdp/washington_gdp.csv")
idaho_df = pd.read_csv("../state_gdp/idaho_gdp.csv")

# dataframe for tables
washington_df = pd.DataFrame(data=washington_df)
idaho_df = pd.DataFrame(data=idaho_df)

# %%
washington_df
# Out:
#        GeoName                                        Description   2005:Q1  \
# 0   Washington                                 All industry total  287547.6
# 1   Washington                                 Private industries  245491.6
# 2   Washington         Agriculture, forestry, fishing and hunting    4789.5
# 3   Washington        Mining, quarrying, and oil and gas extra...     444.2
# 4   Washington                                          Utilities    2944.6
# 5   Washington                                       Construction   13636.2
# 6   Washington                                      Manufacturing   36741.6
# 7   Washington                        Durable goods manufacturing   25988.4
# 8   Washington                     Nondurable goods manufacturing   10753.2
# 9   Washington                                    Wholesale trade   16499.5
# 10  Washington                                       Retail trade   20816.6
# ...

# %%
washington_df.drop(['GeoName'], axis=1, inplace=True)
# washington_df

# %%
# wanting to see the industry total GDP
washington_df.drop(washington_df.index[1:], inplace=True)

# %%
washington_df.drop("Description", axis=1, inplace=True)

# %%
washington_df
# Out:
#     2005:Q1   2005:Q2   2005:Q3   2005:Q4   2006:Q1   2006:Q2   2006:Q3  \
# 0  287547.6  292316.2  293460.5  301379.6  307950.6  311377.5  315564.3
#
#     2006:Q4   2007:Q1   2007:Q2   2007:Q3   2007:Q4   2008:Q1   2008:Q2  \
# 0  322168.5  327561.0  338922.9  347331.8  354281.2  350203.5  354175.3
#
#     2008:Q3   2008:Q4   2009:Q1   2009:Q2   2009:Q3   2009:Q4   2010:Q1  \
# 0  360115.4  354682.1  349424.3  349917.7  349959.6  355678.6  356272.7
#
#     2010:Q2   2010:Q3   2010:Q4   2011:Q1   2011:Q2   2011:Q3   2011:Q4  \
# 0  364862.2  368781.9  372074.2  374002.3  377051.8  379621.0  387624.2
#
#     2012:Q1   2012:Q2   2012:Q3   2012:Q4   2013:Q1   2013:Q2   2013:Q3  \
# 0  395410.5  399945.0  404652.6  402114.2  413912.4  414997.5  422764.3
#
#     2013:Q4   2014:Q1   2014:Q2   2014:Q3   2014:Q4   2015:Q1   2015:Q2  \
# 0  424695.3  429419.3  435640.1  446928.1  450604.4  457749.9  465354.0
#
#     2015:Q3   2015:Q4   2016:Q1   2016:Q2   2016:Q3   2016:Q4   2017:Q1  \
# ...

# %%
# Reflect the DataFrame over its main diagonal by writing rows as columns and vice-versa
washington_df = washington_df.T
washington_df
# Out:
#                 0
# 2005:Q1  287547.6
# 2005:Q2  292316.2
# 2005:Q3  293460.5
# 2005:Q4  301379.6
# 2006:Q1  307950.6
# 2006:Q2  311377.5
# 2006:Q3  315564.3
# 2006:Q4  322168.5
# 2007:Q1  327561.0
# 2007:Q2  338922.9
# 2007:Q3  347331.8
# 2007:Q4  354281.2
# 2008:Q1  350203.5
# 2008:Q2  354175.3
# 2008:Q3  360115.4
# 2008:Q4  354682.1
# 2009:Q1  349424.3
# 2009:Q2  349917.7
# 2009:Q3  349959.6
# 2009:Q4  355678.6
# 2010:Q1  356272.7
# 2010:Q2  364862.2
# 2010:Q3  368781.9
# 2010:Q4  372074.2
# 2011:Q1  374002.3
# 2011:Q2  377051.8
# 2011:Q3  379621.0
# 2011:Q4  387624.2
# 2012:Q1  395410.5
# 2012:Q2  399945.0
# 2012:Q3  404652.6
# 2012:Q4  402114.2
# 2013:Q1  413912.4
# 2013:Q2  414997.5
# 2013:Q3  422764.3
# 2013:Q4  424695.3
# 2014:Q1  429419.3
# 2014:Q2  435640.1
# 2014:Q3  446928.1
# 2014:Q4  450604.4
# 2015:Q1  457749.9
# 2015:Q2  465354.0
# 2015:Q3  472109.2
# 2015:Q4  471545.8
# 2016:Q1  482608.7
# 2016:Q2  482090.8
# 2016:Q3  486253.1
# 2016:Q4  498147.9
# 2017:Q1  506677.3
# ...

# %%
washington_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 69 entries, 2005:Q1 to 2022:Q1
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       69 non-null     float64
# dtypes: float64(1)
# memory usage: 3.1+ KB

# %%
# Renaming the columns, no need for quotations beacuse it's a number (float64)
washington_df.rename(columns = {0 : "washington_dollars_millions"}, inplace=True)
# washington_df

# %%
washington_df.describe()
# Out:
#        washington_dollars_millions
# count                    69.000000
# mean                 448998.263768
# std                  113554.301668
# min                  287547.600000
# 25%                  354682.100000
# 50%                  422764.300000
# 75%                  536324.700000
# max                  703117.000000

# %%
washington_df.plot.line(y="washington_dollars_millions")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Idaho

# %%
idaho_df.head()
# Out:
#   GeoName                                        Description  2005:Q1  \
# 0   Idaho                                 All industry total  47497.0
# 1   Idaho                                 Private industries  40782.5
# 2   Idaho         Agriculture, forestry, fishing and hunting   2313.2
# 3   Idaho        Mining, quarrying, and oil and gas extra...    424.7
# 4   Idaho                                          Utilities    612.3
#
#    2005:Q2  2005:Q3  2005:Q4  2006:Q1  2006:Q2  2006:Q3  2006:Q4  2007:Q1  \
# 0  48324.1  49347.3  49402.8  50612.9  51293.0  50831.7  51765.5  52804.0
# 1  41557.9  42360.3  42199.0  43476.8  43890.5  43618.7  44341.4  45381.2
# 2   2347.2   2217.5   2031.9   2238.9   2295.7   2355.5   2300.5   2989.1
# 3    534.0    774.5    618.8    576.7    635.9    480.8    478.7    499.4
# 4    574.2    621.5    597.7    711.8    723.2    697.2    735.2    716.7
#
#    2007:Q2  2007:Q3  2007:Q4  2008:Q1  2008:Q2  2008:Q3  2008:Q4  2009:Q1  \
# ...

# %%
# Dropping GeoName and Description 
idaho_df.drop({'GeoName', "Description"}, axis=1, inplace=True)

# %%
# Dropping the other industries
idaho_df.drop(idaho_df.index[1:], inplace=True)

# %%
# Transpose the data
idaho_df = idaho_df.T

# %%
idaho_df.rename(columns = {0 : "idaho_dollars_millions"}, inplace=True)
# idaho_df

# %%
idaho_df.describe()
# Out:
#        idaho_dollars_millions
# count               69.000000
# mean             65559.946377
# std              13436.212802
# min              47497.000000
# 25%              55403.500000
# 50%              62229.300000
# 75%              73416.100000
# max             100797.700000

# %%
idaho_df.plot.line(y="idaho_dollars_millions")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Merge Both Datasets
#
# #### https://pandas.pydata.org/docs/user_guide/merging.html (figure 11)

# %%
merged_df = pd.concat([washington_df, idaho_df], axis=1).reindex(washington_df.index)
merged_df
# Out:
#          washington_dollars_millions  idaho_dollars_millions
# 2005:Q1                     287547.6                 47497.0
# 2005:Q2                     292316.2                 48324.1
# 2005:Q3                     293460.5                 49347.3
# 2005:Q4                     301379.6                 49402.8
# 2006:Q1                     307950.6                 50612.9
# 2006:Q2                     311377.5                 51293.0
# 2006:Q3                     315564.3                 50831.7
# 2006:Q4                     322168.5                 51765.5
# 2007:Q1                     327561.0                 52804.0
# 2007:Q2                     338922.9                 53375.7
# 2007:Q3                     347331.8                 54137.5
# 2007:Q4                     354281.2                 55420.8
# 2008:Q1                     350203.5                 55403.5
# 2008:Q2                     354175.3                 56669.4
# ...

# %%
# https://www.geeksforgeeks.org/get-a-list-of-a-particular-column-values-of-a-pandas-dataframe/
# Making the values in the columns to a list
washington_values = merged_df["washington_dollars_millions"].tolist()
# washington_values

# %%
idaho_values = merged_df["idaho_dollars_millions"].tolist()
# idaho_values

# %%
# Getting the index values to a list
time_values = merged_df.index.tolist()
# time_values

# %%
# https://www.geeksforgeeks.org/plot-a-vertical-line-in-matplotlib/
vert_line = time_values[38]
# vert_line

# %% [markdown]
# ### Little explanation
# ### I used the vert_line variable to attach 2014 Q3, x-point and so that the vertical line in the graph shows the point of after the legalization of marijuana and before legalization
# #### https://www.tutorialspoint.com/how-do-you-plot-a-vertical-line-on-a-time-series-plot-in-pandas#:~:text=Using%20panda%20we%20can%20create,%2C%20linestyle%3D%22dashed%22. Used this to look at adding that vertical line

# %%
# https://www.tutorialspoint.com/how-to-make-two-plots-side-by-side-using-python 

from matplotlib import pyplot as plt
xPoints = time_values
y1Points = washington_values
y2Points = idaho_values

plt.subplot(1, 2, 1) # row 1, col 2 index 1
plt.plot(xPoints, y1Points)
plt.axvline(x= vert_line)
plt.title("Washington")
plt.xlabel('X-axis ')
plt.ylabel('Y-axis ')

plt.subplot(1, 2, 2) # index 2
plt.plot(xPoints, y2Points)
plt.axvline(x= vert_line)
plt.title("Idaho")
plt.xlabel('X-axis ')
plt.ylabel('Y-axis ')

plt.show()

# %% [markdown]
# #### look into changing for inflation
