# %% [markdown]
# # Looking over the Colorado marijuana tax
# ##### The data set i'm looking over is from the Colorado Department of Revenue and I looked into this research because of the reliability. This information will give me the volume of sales that were made in Colorado. I can use this to compare to other legalized states and see if there is any relationship among growth of state economy.

# %%
import pandas as pd
import numpy as np 
import plotly.express as px

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df = pd.read_csv("/Users/jonathanho/Desktop/Specs Capstone/colorado_marijuana_tax/Colorado_Marijuana_Tax_Revenue_2014_To_Date.csv")
df
# Out:
#                         Colorado Department of Revenue    Unnamed: 1  \
# 0               Marijuana Tax and Fee Revenue Report ¹           NaN
# 1                                February 2014 to Date           NaN
# 2                                                  NaN           NaN
# 3                                        Revenue Month  Revenue Year
# 4                                                  NaN           NaN
# 5                                                  NaN   Calculation
# 6                                                    1          2014
# 7                                                    2          2014
# 8                                                    3          2014
# 9                                                    4          2014
# 10                                                   5          2014
# 11                                                   6          2014
# 12                                                   7          2014
# ...

# %%
df = pd.DataFrame(data=df)

# %%
# identifying the rows that I want to drop
df.iloc[0:7]
# Out:
#            Colorado Department of Revenue    Unnamed: 1  \
# 0  Marijuana Tax and Fee Revenue Report ¹           NaN
# 1                   February 2014 to Date           NaN
# 2                                     NaN           NaN
# 3                           Revenue Month  Revenue Year
# 4                                     NaN           NaN
# 5                                     NaN   Calculation
#
#               Unnamed: 2         Unnamed: 3             Unnamed: 4  \
# 0                    NaN                NaN                    NaN
# 1                    NaN                NaN                    NaN
# 2                    NaN                NaN                    NaN
# 3   State Sales Tax 2.9%                NaN                    NaN
# 4  State Sales Tax Total  Medical Marijuana  Retail Marijuana ², ³
# 5                  A=B+C                  B                      C
#
#                          Unnamed: 5                         Unnamed: 6  \
# ...

# %%
# dropping the first 8 rows
df = df.drop(df.index[0:7])
df
# Out:
#                         Colorado Department of Revenue Unnamed: 1  \
# 7                                                    2       2014
# 8                                                    3       2014
# 9                                                    4       2014
# 10                                                   5       2014
# 11                                                   6       2014
# 12                                                   7       2014
# 13                                                   8       2014
# 14                                                   9       2014
# 15                                                  10       2014
# 16                                                  11       2014
# 17                                                  12       2014
# 18                                                   1       2015
# 19                                                   2       2015
# ...

# %%
# looking for the bottom half to drop
df.iloc[100:109]
# Out:
#                         Colorado Department of Revenue Unnamed: 1 Unnamed: 2  \
# 107                                                NaN        NaN        NaN
# 108  Source: Revenue collected monthly as posted in...        NaN        NaN
# 109  ¹ Tax remitted includes marijuana tax, license...        NaN        NaN
# 110  ² Per §39-28.8-202, C.R.S., the retail marijua...        NaN        NaN
# 111  ³ Per §39-26-729, C.R.S., retail marijuana, re...        NaN        NaN
# 112  ⁴ Total includes collections not yet allocated...        NaN        NaN
# 113                                                NaN        NaN        NaN
# 114  Prepared by: Office of Research and Analysis, ...        NaN        NaN
# 115                            Publish date: June 2022        NaN        NaN
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 107        NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
# dropping the first the last few rows
df.drop(df.index[100:109], inplace = True)
df
# Out:
#     Colorado Department of Revenue Unnamed: 1   Unnamed: 2   Unnamed: 3  \
# 7                                2       2014  $1,330,209     $913,519
# 8                                3       2014  $1,460,429   $1,022,176
# 9                                4       2014  $1,569,405     $999,900
# 10                               5       2014  $1,559,710     $919,982
# 11                               6       2014  $1,569,454     $927,330
# 12                               7       2014  $1,530,968     $830,861
# 13                               8       2014  $1,659,789     $838,711
# 14                               9       2014  $1,892,780     $935,807
# 15                              10       2014  $1,795,545     $908,630
# 16                              11       2014  $1,816,579     $928,329
# 17                              12       2014  $1,649,935     $772,472
# 18                               1       2015  $1,874,283     $889,249
# ...

# %%
# looking at the types in order to combine the values 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 7 to 106
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Colorado Department of Revenue  100 non-null    object
#  1   Unnamed: 1                      100 non-null    object
#  2   Unnamed: 2                      100 non-null    object
#  3   Unnamed: 3                      100 non-null    object
#  4   Unnamed: 4                      100 non-null    object
#  5   Unnamed: 5                      100 non-null    object
#  6   Unnamed: 6                      100 non-null    object
#  7   Unnamed: 7                      100 non-null    object
#  8   Unnamed: 8                      58 non-null     object
#  9   Unnamed: 9                      58 non-null     object
#  10  Unnamed: 10                     58 non-null     object
#  11  Unnamed: 11                     100 non-null    object
# ...

# %%
# renaming columns 
df.rename(columns = {"Unnamed: 1":"year", "Unnamed: 2":"state_sales_tax_total", "Unnamed: 3":"medical_marijuana", "Unnamed: 4":"retail_marijuana"})
# Out:
#     Colorado Department of Revenue  year state_sales_tax_total  \
# 7                                2  2014           $1,330,209
# 8                                3  2014           $1,460,429
# 9                                4  2014           $1,569,405
# 10                               5  2014           $1,559,710
# 11                               6  2014           $1,569,454
# 12                               7  2014           $1,530,968
# 13                               8  2014           $1,659,789
# 14                               9  2014           $1,892,780
# 15                              10  2014           $1,795,545
# 16                              11  2014           $1,816,579
# 17                              12  2014           $1,649,935
# 18                               1  2015           $1,874,283
# 19                               2  2015           $1,808,419
# 20                               3  2015           $1,919,649
# ...
